# %%
from onekey_algo.mietb.patch_preprocess import patch2predict

sample_dir = r'D:\20250416-LiHaiYu\patches1'
patch2predict(sample_dir, num_workers=8, batch_size=16)
# Out:
# [2025-09-12 00:30:31 - patch2predict.py:  39]	INFO	Dataloader mode, using cuda
# [2025-09-12 00:30:31 - patch2predict.py:  48]	INFO	D:\20250416-LiHaiYu\patches1\HBre-Duc140Sur-01一共有37908样本。
# [2025-09-12 00:30:31 - eval_classification.py:  35]	INFO	正在预测中，已完成：0, 完成率：0.0000%
# [2025-09-12 00:30:47 - eval_classification.py:  35]	INFO	正在预测中，已完成：1000, 完成率：2.6380%
# [2025-09-12 00:31:01 - eval_classification.py:  35]	INFO	正在预测中，已完成：2000, 完成率：5.2759%
# [2025-09-12 00:31:15 - eval_classification.py:  35]	INFO	正在预测中，已完成：3000, 完成率：7.9139%
# [2025-09-12 00:31:29 - eval_classification.py:  35]	INFO	正在预测中，已完成：4000, 完成率：10.5519%
# [2025-09-12 00:31:44 - eval_classification.py:  35]	INFO	正在预测中，已完成：5000, 完成率：13.1898%
